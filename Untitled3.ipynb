# %%
import pandas as pd

# %%
import matplotlib.pyplot as mat

# %%
import seaborn as sea

# %% [markdown]
# #  About Dataset
#              This dataset contains the details and features of different models of different cars and information about cars and if the purchase was bad or not.

# %%
car=pd.read_csv("D:/Pythoon Folder/car_kick.csv")

# %%
car
# Out:
#           PurchDate  VehYear  VehicleAge   VehOdo  \
# 0      1.289952e+09   2006.0           4  51954.0
# 1      1.242691e+09   2005.0           4  89127.0
# 2      1.248221e+09   2006.0           3  71271.0
# 3      1.285718e+09   2008.0           2  83338.0
# 4      1.237334e+09   2007.0           2  58698.0
# ...             ...      ...         ...      ...
# 67206  1.285805e+09   2008.0           2  56072.0
# 67207  1.274918e+09   2004.0           6  94232.0
# 67208  1.280448e+09   2004.0           6  79534.0
# 67209  1.285200e+09   2003.0           7  79394.0
# 67210  1.288742e+09   2004.0           6  94491.0
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# 0                                 6197.0                           7062.0
# 1                                 3688.0                           4783.0
# 2                                 6897.0                           8449.0
# ...

# %%
car.describe()
# Out:
#           PurchDate       VehYear    VehicleAge         VehOdo  \
# count  6.721100e+04  67211.000000  67211.000000   67211.000000
# mean   1.263166e+09   2005.352606      4.168588   71734.558971
# std    1.820779e+07      1.727873      1.707501   14387.245482
# min    1.231114e+09   2001.000000      0.000000    5368.000000
# 25%    1.247789e+09   2004.000000      3.000000   62163.000000
# 50%    1.264032e+09   2005.000000      4.000000   73530.000000
# 75%    1.279152e+09   2007.000000      5.000000   82530.000000
# max    1.293667e+09   2010.000000      9.000000  115717.000000
#
#        MMRAcquisitionAuctionAveragePrice  MMRAcquisitionAuctionCleanPrice  \
# count                       67211.000000                     67211.000000
# mean                         6162.054589                      7411.975123
# std                          2452.884994                      2714.884242
# min                             0.000000                         0.000000
# ...

# %% [markdown]
# ###### In this dataset ,it shows us the basic statistical data of dataset,Like Count, Mean, STD, min, 25th percentile, 50th percentile, 75th percentile and max functions.

# %%
mat.boxplot(car['MMRAcquisitionAuctionAveragePrice'])
mat.show()

# %% [markdown]
# ###### Boxplot for 'MMRAcquisitionAuctionAveragePrice'' variable is shown from the dataset.where there are outliers in the 35000,Here we can see that the boxplot lies between '0' to '10000'

# %%
mat.boxplot(car['MMRAcquisitionAuctionAveragePrice'])
mat.yscale('log')
mat.show()

# %% [markdown]
# ###### Here log has been taken for 'Y' axis for the better representaion of the boxplot

# %%
mat.hist(car['MMRAcquisitionAuctionAveragePrice'],color='c')
mat.show()

# %% [markdown]
# ###### Here histogram is created for 'MMRAcquisitionAuctionAveragePrice' variable.the histogram shows that the around 4800 to 10200 cars' .auction has peak '30000'.

# %%
mat.hist(car['MMRAcquisitionAuctionAveragePrice'],color='c')
mat.yscale('log')
mat.show()

# %% [markdown]
# ###### Here log has been taken for 'Y' axis for the better representaion of the boxplot

# %%
mat.scatter(car['MMRAcquisitionAuctionAveragePrice'],car['MMRAcquisitionAuctionCleanPrice'],color='c')
mat.show()

# %% [markdown]
# ###### In this scatterplot, variables ''MMRAcquisitionAuctionAveragePrice'' and ''MMRAcquisitionAuctionCleanPrice''.there is outlier lies in above 35000 in yaxis,the maximum value of data in the dataset is occured between the values of (10 to 18000) in x-axis.

# %%
sea.distplot(car['WarrantyCost'],color='r')
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### Distplot is created for the variable "WarrantyCost"here the data has its peak value from 500 to 1800,the value decrease on the range of 1800 to 2800.

# %%
sea.distplot(car['WarrantyCost'][:5000],rug=True,color='r')
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ######  Here we performed the rug plotting in scatter plot for the variable 'WarrantyCost' with valuesmore than 2000.

# %%
sea.distplot(car['WarrantyCost'],hist=False,color='r')
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### Distplot is created for the variable "WarrantyCost" and here the histogram of this plotting were disabled.

# %%
sea.boxplot(car['VehicleAge'])
mat.title('Age')
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ###### The boxplot shows that high number of vehicleage have 3 to 5 and the outliers shows the some of the vechile age were above 8

# %%
sea.boxplot(y=car['VehicleAge'])
mat.title('Age')
mat.show()

# %% [markdown]
# ###### The boxplot shows that high number of vehicleage have 3 to 5 and the outliers shows the some of the vechile age were above 8.But the vehicleage is in the y axis.

# %%
sea.jointplot('MMRAcquisitionAuctionAveragePrice','MMRAcquisitionRetailAveragePrice',car,kind='reg',color='r')
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ###### Jointplot is created for two variables "MMRAcquisitionAuctionAveragePrice" and "MMRAcquisitionRetailAveragePrice"

# %%
car=car[(car.VehYear<2003.0)&(car.MMRCurrentAuctionCleanPrice<4732.0)]
sea.jointplot('VehYear','MMRCurrentAuctionCleanPrice',car,kind="resid",color='k')
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ###### The jointplot shows that the VehYear 2001.0 to 2002.0 have MMRCurrentAuctionCleanPrice  around  100 to 1300.

# %%
car=car[(car.VehYear<2003.0)&(car.MMRCurrentAuctionCleanPrice<4732.0)]
sea.jointplot(x='VehYear',y='MMRCurrentAuctionCleanPrice',data=car,kind='hex',color='gray')
mat.show()

# %% [markdown]
# ###### Here jointplot is created for the variables 'VehYear' and 'MMRCurrentAuctionCleanPrice' with the value representaion by using hexagon on gray color.

# %%
x = list(car.iloc[:,5])
y = list(car.iloc[:,7])
mat.bar(x,y,color='g')
mat.title("VehicleAge vs VehOdo")
mat.xlabel('VehicleAge')
mat.ylabel('VehOdo')
# Out:
# Text(0, 0.5, 'VehOdo')

# %% [markdown]
# ###### Here the barplot is created by taking 'VehicleAge' in x-axis and 'VehOdo' in y-axis of the vehicles. Here the highest value of the vechileage is in between 2200 to 4000 with the vechileodo 9000.

# %%
x = list(car.iloc[:,5])
y = list(car.iloc[:,7])
mat.bar(x,y,color='g')
mat.title("VehicleAge vs VehOdo ")
mat.xlabel('VehicleAge')
mat.ylabel('VehOdo')
mat.xticks(color='g', rotation='85', fontweight='bold', fontsize='12', horizontalalignment='right')
# Out:
# (array([-2000.,     0.,  2000.,  4000.,  6000.,  8000., 10000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ###### Here the barplot is created by taking 'VehicleAge' in x-axis and 'VehOdo' in y-axis of the vehicles. Here the highest value of the vechileage is in between 2200 to 4000 with the vechileodo 9000. Here we change the rotation of the x axis value.

# %%
mat.subplot(3,3,1)
sea.distplot(car['VehicleAge'])

mat.subplot(3,3,2)
sea.distplot(car['VehOdo'])

mat.subplot(3,3,3)
sea.distplot(car['MMRAcquisitionAuctionAveragePrice'])

mat.tight_layout()
mat.show()
# Out:
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\91638\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ###### Subplots have been created for the variables VehicleAge,,city_mpg,Popularity
